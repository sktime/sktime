# %% [markdown]
# # LLM-based Time Series Assistant Demo
# This notebook demonstrates a minimal agentic workflow using sktime.

# %%
from utils import load_sample_data
from agent import run_agent

# %%
data = load_sample_data()
data.head()

# %%
queries = [
    "forecast next 12 steps",
    "what is the trend?",
    "detect anomalies",
]

for q in queries:
    print("=" * 80)
    print(run_agent(q, data))
