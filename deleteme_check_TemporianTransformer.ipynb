# %%
from sktime.transformations.series.temporian import TemporianTransformer
from sktime.utils.estimator_checks import check_estimator

# %%
check_estimator(TemporianTransformer)
# Out:
# FAILED: test_fit_does_not_overwrite_hyper_params[TemporianTransformer-TransformerFitTransformSeriesUnivariate]
# FAILED: test_fit_does_not_overwrite_hyper_params[TemporianTransformer-TransformerFitTransformSeriesMultivariate]
# FAILED: test_fit_does_not_overwrite_hyper_params[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY]
# FAILED: test_fit_does_not_overwrite_hyper_params[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY]
# FAILED: test_fit_does_not_overwrite_hyper_params[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]
# FAILED: test_fit_idempotent[TemporianTransformer-TransformerFitTransformSeriesUnivariate-transform]
# FAILED: test_fit_idempotent[TemporianTransformer-TransformerFitTransformSeriesMultivariate-transform]
# FAILED: test_fit_idempotent[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-transform]
# FAILED: test_fit_idempotent[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-transform]
# FAILED: test_fit_idempotent[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]
# FAILED: test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformSeriesUnivariate-transform]
# FAILED: test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformSeriesMultivariate-transform]
# FAILED: test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-transform]
# FAILED: test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-transform]
# FAILED: test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]
# FAILED: test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformSeriesUnivariate-transform]
# FAILED: test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformSeriesMultivariate-transform]
# FAILED: test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-transform]
# FAILED: test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-transform]
# FAILED: test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]
# FAILED: test_persistence_via_pickle[TemporianTransformer-TransformerFitTransformSeriesUnivariate-transform]
# FAILED: test_persistence_via_pickle[TemporianTransformer-TransformerFitTransformSeriesMultivariate-transform]
# FAILED: test_persistence_via_pickle[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-transform]
# FAILED: test_persistence_via_pickle[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-transform]
# FAILED: test_persistence_via_pickle[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]
# FAILED: test_save_estimators_to_file[TemporianTransformer-TransformerFitTransformSeriesUnivariate-transform]
# FAILED: test_save_estimators_to_file[TemporianTransformer-TransformerFitTransformSeriesMultivariate-transform]
# FAILED: test_save_estimators_to_file[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-transform]
# FAILED: test_save_estimators_to_file[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-transform]
# FAILED: test_save_estimators_to_file[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]
# FAILED: test_fit_transform_output[TemporianTransformer-TransformerFitTransformSeriesUnivariate]
# FAILED: test_fit_transform_output[TemporianTransformer-TransformerFitTransformSeriesMultivariate]
# FAILED: test_fit_transform_output[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY]
# FAILED: test_fit_transform_output[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY]
# FAILED: test_fit_transform_output[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]
# {'test_clone[TemporianTransformer]': 'PASSED',
#  'test_constructor[TemporianTransformer]': 'PASSED',
#  'test_create_test_instance[TemporianTransformer]': 'PASSED',
#  'test_create_test_instances_and_names[TemporianTransformer]': 'PASSED',
#  'test_estimator_tags[TemporianTransformer]': 'PASSED',
#  'test_get_params[TemporianTransformer]': 'PASSED',
#  'test_get_test_params[TemporianTransformer]': 'PASSED',
#  'test_has_common_interface[TemporianTransformer]': 'PASSED',
#  'test_inheritance[TemporianTransformer]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-TransformerFitTransformSeriesUnivariate-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-TransformerFitTransformSeriesUnivariate-1]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-TransformerFitTransformSeriesMultivariate-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-TransformerFitTransformSeriesMultivariate-1]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-1]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-1]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-1]': 'PASSED',
#  'test_no_cross_test_side_effects_part1[TemporianTransformer]': 'PASSED',
#  'test_no_cross_test_side_effects_part2[TemporianTransformer]': 'PASSED',
#  'test_repr[TemporianTransformer]': 'PASSED',
#  'test_set_params[TemporianTransformer]': 'PASSED',
#  'test_set_params_sklearn[TemporianTransformer]': 'PASSED',
#  'test_valid_estimator_class_tags[TemporianTransformer]': 'PASSED',
#  'test_valid_estimator_tags[TemporianTransformer]': 'PASSED',
#  'test_dl_constructor_initializes_deeply[TemporianTransformer]': 'PASSED',
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-TransformerFitTransformSeriesUnivariate]': _pickle.PicklingError("Can't pickle <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: it's not found as sktime.transformations.series.temporian.TemporianTransformer.get_test_params.<locals>.<lambda>",
#                        'PicklingError while hashing <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: PicklingError("Can\'t pickle <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: it\'s not found as sktime.transformations.series.temporian.TemporianTransformer.get_test_params.<locals>.<lambda>")'),
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-TransformerFitTransformSeriesMultivariate]': _pickle.PicklingError("Can't pickle <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: it's not found as sktime.transformations.series.temporian.TemporianTransformer.get_test_params.<locals>.<lambda>",
#                        'PicklingError while hashing <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: PicklingError("Can\'t pickle <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: it\'s not found as sktime.transformations.series.temporian.TemporianTransformer.get_test_params.<locals>.<lambda>")'),
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY]': _pickle.PicklingError("Can't pickle <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: it's not found as sktime.transformations.series.temporian.TemporianTransformer.get_test_params.<locals>.<lambda>",
#                        'PicklingError while hashing <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: PicklingError("Can\'t pickle <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: it\'s not found as sktime.transformations.series.temporian.TemporianTransformer.get_test_params.<locals>.<lambda>")'),
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY]': _pickle.PicklingError("Can't pickle <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: it's not found as sktime.transformations.series.temporian.TemporianTransformer.get_test_params.<locals>.<lambda>",
#                        'PicklingError while hashing <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: PicklingError("Can\'t pickle <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: it\'s not found as sktime.transformations.series.temporian.TemporianTransformer.get_test_params.<locals>.<lambda>")'),
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': _pickle.PicklingError("Can't pickle <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: it's not found as sktime.transformations.series.temporian.TemporianTransformer.get_test_params.<locals>.<lambda>",
#                        'PicklingError while hashing <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: PicklingError("Can\'t pickle <function TemporianTransformer.get_test_params.<locals>.<lambda> at 0x15568fa30>: it\'s not found as sktime.transformations.series.temporian.TemporianTransformer.get_test_params.<locals>.<lambda>")'),
#  'test_fit_idempotent[TemporianTransformer-TransformerFitTransformSeriesUnivariate-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_fit_idempotent[TemporianTransformer-TransformerFitTransformSeriesMultivariate-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_fit_idempotent[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_fit_idempotent[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-transform]': TypeError('unsupported Type Index'),
#  'test_fit_idempotent[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': TypeError('unsupported Type Index'),
#  'test_fit_returns_self[TemporianTransformer-TransformerFitTransformSeriesUnivariate]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-TransformerFitTransformSeriesMultivariate]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-TransformerFitTransformSeriesUnivariate]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-TransformerFitTransformSeriesMultivariate]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformSeriesUnivariate-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformSeriesUnivariate-get_fitted_params]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformSeriesMultivariate-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformSeriesMultivariate-get_fitted_params]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-get_fitted_params]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-transform]': TypeError('unsupported Type Index'),
#  'test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-get_fitted_params]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': TypeError('unsupported Type Index'),
#  'test_methods_have_no_side_effects[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-get_fitted_params]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformSeriesUnivariate-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformSeriesUnivariate-get_fitted_params]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformSeriesMultivariate-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformSeriesMultivariate-get_fitted_params]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-get_fitted_params]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-transform]': TypeError('unsupported Type Index'),
#  'test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-get_fitted_params]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': TypeError('unsupported Type Index'),
#  'test_non_state_changing_method_contract[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-get_fitted_params]': 'PASSED',
#  'test_persistence_via_pickle[TemporianTransformer-TransformerFitTransformSeriesUnivariate-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_persistence_via_pickle[TemporianTransformer-TransformerFitTransformSeriesMultivariate-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_persistence_via_pickle[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_persistence_via_pickle[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-transform]': TypeError('unsupported Type Index'),
#  'test_persistence_via_pickle[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': TypeError('unsupported Type Index'),
#  'test_raises_not_fitted_error[TemporianTransformer-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-TransformerFitTransformSeriesUnivariate-get_fitted_params]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-TransformerFitTransformSeriesMultivariate-get_fitted_params]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-get_fitted_params]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-get_fitted_params]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-get_fitted_params]': 'PASSED',
#  'test_save_estimators_to_file[TemporianTransformer-TransformerFitTransformSeriesUnivariate-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_save_estimators_to_file[TemporianTransformer-TransformerFitTransformSeriesMultivariate-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_save_estimators_to_file[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY-transform]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_save_estimators_to_file[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY-transform]': TypeError('unsupported Type Index'),
#  'test_save_estimators_to_file[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': TypeError('unsupported Type Index'),
#  'test_capability_inverse_tag_is_correct[TemporianTransformer]': 'PASSED',
#  'test_fit_transform_output[TemporianTransformer-TransformerFitTransformSeriesUnivariate]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_fit_transform_output[TemporianTransformer-TransformerFitTransformSeriesMultivariate]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_fit_transform_output[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY]': ValueError("Need to specify at least one of 'labels', 'index' or 'columns'"),
#  'test_fit_transform_output[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY]': TypeError('unsupported Type Index'),
#  'test_fit_transform_output[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': TypeError('unsupported Type Index'),
#  'test_remember_data_tag_is_correct[TemporianTransformer]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-TransformerFitTransformSeriesUnivariate]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-TransformerFitTransformSeriesMultivariate]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-TransformerFitTransformSeriesUnivariateWithY]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-TransformerFitTransformPanelUnivariateWithClassY]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': 'PASSED'}
