# %%
from sktime.transformations.series.temporian import TemporianTransformer
from sktime.utils.estimator_checks import check_estimator

# %%
check_estimator(TemporianTransformer)
# Out:
# All tests PASSED!
# {'test_clone[TemporianTransformer-0]': 'PASSED',
#  'test_clone[TemporianTransformer-1]': 'PASSED',
#  'test_constructor[TemporianTransformer]': 'PASSED',
#  'test_create_test_instance[TemporianTransformer]': 'PASSED',
#  'test_create_test_instances_and_names[TemporianTransformer]': 'PASSED',
#  'test_estimator_tags[TemporianTransformer]': 'PASSED',
#  'test_get_params[TemporianTransformer-0]': 'PASSED',
#  'test_get_params[TemporianTransformer-1]': 'PASSED',
#  'test_get_test_params[TemporianTransformer]': 'PASSED',
#  'test_has_common_interface[TemporianTransformer]': 'PASSED',
#  'test_inheritance[TemporianTransformer]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate-1]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate-1]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY-1]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY-1]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-1]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate-1]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate-1]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY-1]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY-1]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-0]': 'PASSED',
#  'test_no_between_test_case_side_effects[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-1]': 'PASSED',
#  'test_no_cross_test_side_effects_part1[TemporianTransformer-0]': 'PASSED',
#  'test_no_cross_test_side_effects_part1[TemporianTransformer-1]': 'PASSED',
#  'test_no_cross_test_side_effects_part2[TemporianTransformer-0]': 'PASSED',
#  'test_no_cross_test_side_effects_part2[TemporianTransformer-1]': 'PASSED',
#  'test_repr[TemporianTransformer-0]': 'PASSED',
#  'test_repr[TemporianTransformer-1]': 'PASSED',
#  'test_set_params[TemporianTransformer-0]': 'PASSED',
#  'test_set_params[TemporianTransformer-1]': 'PASSED',
#  'test_set_params_sklearn[TemporianTransformer]': 'PASSED',
#  'test_valid_estimator_class_tags[TemporianTransformer]': 'PASSED',
#  'test_valid_estimator_tags[TemporianTransformer-0]': 'PASSED',
#  'test_valid_estimator_tags[TemporianTransformer-1]': 'PASSED',
#  'test_dl_constructor_initializes_deeply[TemporianTransformer]': 'PASSED',
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate]': 'PASSED',
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate]': 'PASSED',
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY]': 'PASSED',
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY]': 'PASSED',
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': 'PASSED',
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate]': 'PASSED',
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate]': 'PASSED',
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY]': 'PASSED',
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY]': 'PASSED',
#  'test_fit_does_not_overwrite_hyper_params[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': 'PASSED',
#  'test_fit_idempotent[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_fit_idempotent[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_fit_idempotent[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_fit_idempotent[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_fit_idempotent[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_fit_idempotent[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_fit_idempotent[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_fit_idempotent[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_fit_idempotent[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_fit_idempotent[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY]': 'PASSED',
#  'test_fit_returns_self[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY]': 'PASSED',
#  'test_fit_updates_state[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate-get_fitted_params]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate-get_fitted_params]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY-get_fitted_params]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY-get_fitted_params]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-get_fitted_params]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate-get_fitted_params]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate-get_fitted_params]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY-get_fitted_params]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY-get_fitted_params]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_methods_have_no_side_effects[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-get_fitted_params]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_multiprocessing_idempotent[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate-get_fitted_params]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate-get_fitted_params]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY-get_fitted_params]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY-get_fitted_params]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-get_fitted_params]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate-get_fitted_params]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate-get_fitted_params]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY-get_fitted_params]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY-get_fitted_params]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_non_state_changing_method_contract[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-get_fitted_params]': 'PASSED',
#  'test_persistence_via_pickle[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_persistence_via_pickle[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_persistence_via_pickle[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_persistence_via_pickle[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_persistence_via_pickle[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_persistence_via_pickle[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_persistence_via_pickle[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_persistence_via_pickle[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_persistence_via_pickle[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_persistence_via_pickle[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate-get_fitted_params]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate-get_fitted_params]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY-get_fitted_params]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY-get_fitted_params]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-get_fitted_params]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate-get_fitted_params]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate-get_fitted_params]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY-get_fitted_params]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY-get_fitted_params]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_raises_not_fitted_error[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-get_fitted_params]': 'PASSED',
#  'test_save_estimators_to_file[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_save_estimators_to_file[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_save_estimators_to_file[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_save_estimators_to_file[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_save_estimators_to_file[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_save_estimators_to_file[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate-transform]': 'PASSED',
#  'test_save_estimators_to_file[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate-transform]': 'PASSED',
#  'test_save_estimators_to_file[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY-transform]': 'PASSED',
#  'test_save_estimators_to_file[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY-transform]': 'PASSED',
#  'test_save_estimators_to_file[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit-transform]': 'PASSED',
#  'test_capability_inverse_tag_is_correct[TemporianTransformer-0]': 'PASSED',
#  'test_capability_inverse_tag_is_correct[TemporianTransformer-1]': 'PASSED',
#  'test_fit_transform_output[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate]': 'PASSED',
#  'test_fit_transform_output[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate]': 'PASSED',
#  'test_fit_transform_output[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY]': 'PASSED',
#  'test_fit_transform_output[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY]': 'PASSED',
#  'test_fit_transform_output[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': 'PASSED',
#  'test_fit_transform_output[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate]': 'PASSED',
#  'test_fit_transform_output[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate]': 'PASSED',
#  'test_fit_transform_output[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY]': 'PASSED',
#  'test_fit_transform_output[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY]': 'PASSED',
#  'test_fit_transform_output[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': 'PASSED',
#  'test_remember_data_tag_is_correct[TemporianTransformer-0]': 'PASSED',
#  'test_remember_data_tag_is_correct[TemporianTransformer-1]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-0-TransformerFitTransformSeriesUnivariate]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-0-TransformerFitTransformSeriesMultivariate]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-0-TransformerFitTransformSeriesUnivariateWithY]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-0-TransformerFitTransformPanelUnivariateWithClassY]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-0-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-1-TransformerFitTransformSeriesUnivariate]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-1-TransformerFitTransformSeriesMultivariate]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-1-TransformerFitTransformSeriesUnivariateWithY]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-1-TransformerFitTransformPanelUnivariateWithClassY]': 'PASSED',
#  'test_transform_inverse_transform_equivalent[TemporianTransformer-1-TransformerFitTransformPanelUnivariateNumpyWithClassYOnlyFit]': 'PASSED'}
