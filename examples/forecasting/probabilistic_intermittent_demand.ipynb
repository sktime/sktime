# %% [markdown]
# # Probabilistic Forecasting of Intermittent Demand
#
# ## Intermittent series
#
# In this notebook we'll explore the use of the `HurdleDemandForecaster` from the `sktime` library to forecast intermittent demand time series. This forecaster uses a Bayesian approach to model the series as a combination of a Bernoulli distributed variable for modeling if there's demand, together with a Poisson or Negative-Binomial distributed variable for deciding the magnitude. To that end, we'll use a dataset from Joaquin Amat Rodrigo's [Estadistica-machine-learning-python repo](https://github.com/JoaquinAmatRodrigo/Estadistica-machine-learning-python).
#
# We begin by fetching it

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/JoaquinAmatRodrigo/Estadistica-machine-learning-python/master/data/intermittent_demand.csv"
data = y = pd.read_csv(url, sep=",", parse_dates=[0], index_col="date_time").squeeze(1)

data.head()
# Out:
# date_time
# 2011-01-01 00:00:00    0.0
# 2011-01-01 01:00:00    0.0
# 2011-01-01 02:00:00    0.0
# 2011-01-01 03:00:00    0.0
# 2011-01-01 04:00:00    0.0
# Name: users, dtype: float64

# %% [markdown]
# We'll defer the analysis to the [(fantastic) accompanying Notebook](https://cienciadedatos.net/documentos/py48-intermittent-demand-forecasting) (authored by Joaquin Amat Rodrigo). However, we'll take another approach by using Fourier features instead of date time features.
#
# We split the data into a training and test set.

# %%
from sklearn.model_selection import train_test_split

y_train, y_test = train_test_split(y, test_size=0.2, random_state=42, shuffle=False)

# %% [markdown]
# Next up, let's fit the model to the data

# %%
import numpyro
from prophetverse.engine import MCMCInferenceEngine

from sktime.forecasting.hurdle_demand import HurdleDemandForecaster
from sktime.transformations.compose import YtoX
from sktime.transformations.series.fourier import FourierFeatures

numpyro.set_host_device_count(4)
numpyro.set_platform("cpu")

engine = MCMCInferenceEngine(
    num_samples=1_000,
    num_warmup=5_000,
    num_chains=4,
    r_hat=1.1,
    dense_mass=[("probability/beta",), ("demand/beta",)],
)

pipeline = (
    YtoX()  # this only serves as a way to pass the Fourier features
    ** FourierFeatures([24, 7 * 24], [2, 4], keep_original_columns=False)
    ** HurdleDemandForecaster(inference_engine=engine)
)
pipeline.fit(y_train)
# Out:
# WARNING:2025-08-06 12:49:08,265:jax._src.xla_bridge:872: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# ...
#   0%|          | 0/6000 [00:00<?, ?it/s]
# ForecastingPipeline(steps=[YtoX(),
#                            FourierFeatures(fourier_terms_list=[2, 4],
#                                            sp_list=[24, 168]),
#                            HurdleDemandForecaster(inference_engine=MCMCInferenceEngine(dense_mass=[('probability/beta',),
#                                                                                                    ('demand/beta',)],
#                                                                                        num_chains=4,
#                                                                                        num_warmup=5000,
#                                                                                        r_hat=1.1))])

# %% [markdown]
# Probabilistically forecasting the series a week into the future yields

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = (12, 6)

y_hat = pipeline.predict_quantiles(np.arange(1, 7 * 24 + 1), alpha=[0.05, 0.95])

fig, ax = plt.subplots()

ax.fill_between(
    y_hat.index,
    y_hat.iloc[:, 0],
    y_hat.iloc[:, 1],
    alpha=0.4,
    label="90% prediction interval",
    color="salmon",
)

ax.plot(y_test.iloc[: y_hat.shape[0]], label="test")
plt.legend()

plt.show()

# %% [markdown]
# We see that the model captures the overall behaviour of the series, but the magnitude being off. This is most likely since the magnitude changes over time, which we can verify by simply plotting it

# %%
y_train[y_train > 0].rolling(7 * 24).mean().plot()
# Out:
# <Axes: xlabel='date_time'>

# %% [markdown]
# Let's try to add this as a feature to the model. We assume that the data is available at the next time step

# %%
x_train = y_train.shift(1).pipe(np.log1p).rolling(7 * 24).mean().to_frame().bfill()

pipeline = FourierFeatures(
    [24, 7 * 24], [2, 4], keep_original_columns=True
) ** HurdleDemandForecaster(inference_engine=engine)
pipeline.fit(y_train, x_train)
# Out:
# ...
#   0%|          | 0/6000 [00:00<?, ?it/s]
# ForecastingPipeline(steps=[FourierFeatures(fourier_terms_list=[2, 4],
#                                            keep_original_columns=True,
#                                            sp_list=[24, 168]),
#                            HurdleDemandForecaster(inference_engine=MCMCInferenceEngine(dense_mass=[('probability/beta',),
#                                                                                                    ('demand/beta',)],
#                                                                                        num_chains=4,
#                                                                                        num_warmup=5000,
#                                                                                        r_hat=1.1))])

# %% [markdown]
# And predicting

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (12, 6)

y_test_index = y_test.index[: 7 * 24 + 1]

combined_index = x_train.index.union(y_test_index)
x_test = x_train.reindex(combined_index).ffill().loc[y_test_index]

y_hat = pipeline.predict_quantiles(y_test_index, x_test, alpha=[0.05, 0.95])

fig, ax = plt.subplots()

ax.fill_between(
    y_hat.index,
    y_hat.iloc[:, 0],
    y_hat.iloc[:, 1],
    alpha=0.4,
    label="90% prediction interval",
    color="salmon",
)

ax.plot(y_test.iloc[: y_hat.shape[0]], label="test")
plt.legend()

plt.show()

# %% [markdown]
# Adding the rolling mean feature yields a significant (visual) improvement to the forecasting of the results.

# %% [markdown]
# ## Erratic
#
# For our next scenario, we'll consider a more erratic series than the data we looked at above. We'll take a look at the "PBS" dataset available in sktime. Loading it yields

# %%
from sktime.datasets import load_PBS_dataset

data = load_PBS_dataset()
data.index = data.index.to_timestamp() + pd.tseries.offsets.MonthEnd(0)

y_train, y_test = train_test_split(data, test_size=0.3, shuffle=False)

y_train.plot()
# Out:
# <Axes: xlabel='Period'>

# %% [markdown]
# In this dataset we don't have the benefit of having a very clear seasonal pattern. To showcase instances when we don't have any obvious regressors, we skip that entirely and model the probability and demand as latent stochastic processes. We'll assume that demand is mean reverting, and that the probability of demand is a random walk.

# %%
engine = MCMCInferenceEngine(
    num_samples=1_000, num_warmup=1_000, num_chains=4, r_hat=1.1
)
model = HurdleDemandForecaster(
    time_varying_demand="ar", time_varying_probability="rw", inference_engine=engine
)

model.fit(y_train)
# Out:
# ...
#   0%|          | 0/2000 [00:00<?, ?it/s]
# HurdleDemandForecaster(inference_engine=MCMCInferenceEngine(num_chains=4,
#                                                             num_warmup=1000,
#                                                             r_hat=1.1),
#                        time_varying_demand='ar', time_varying_probability='rw')

# %% [markdown]
# Let's also include the default Croston predictions

# %%
from sktime.forecasting.croston import Croston

croston = Croston()
croston.fit(y_train)

y_hat_croston = croston.predict(y_test.index)

# %% [markdown]
# And let's take a look at the predictions

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (12, 6)

y_hat = model.predict_quantiles(y_test.index, alpha=[0.05, 0.5, 0.95])

fig, ax = plt.subplots()

ax.fill_between(
    y_hat.index,
    y_hat.iloc[:, 0],
    y_hat.iloc[:, -1],
    alpha=0.4,
    label="90% prediction interval",
    color="salmon",
)

ax.plot(y_hat.iloc[:, 1], label="median")
ax.plot(y_hat_croston, label="Croston")

ax.plot(y_test, label="test")
plt.legend()

plt.show()

# %% [markdown]
# Comparing MAE

# %%
from sktime.performance_metrics.forecasting import mean_absolute_error

nbin_error = mean_absolute_error(y_test, y_hat.iloc[:, 1])
croston_error = mean_absolute_error(y_test, y_hat_croston)

print(f"MAE for Negative-Binomial model: {nbin_error:.2f}")
print(f"MAE for Croston model: {croston_error:.2f}")
# Out:
# MAE for Negative-Binomial model: 0.16
# MAE for Croston model: 1.84
