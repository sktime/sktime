# %% [markdown]
# ## Testing of Time-Series Forest Implementation

# %%
from sktime.ts_forest import TSForest
from utilities.load_data import load_from_web_to_xdataframe
import numpy as np
import pandas as pd

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-7f62a785461f> in <module>
#       1 from sktime.ts_forest import TSForest
# ----> 2 from utilities.load_data import load_from_web_to_xdataframe
#       3 import numpy as np
#       4 import pandas as pd
#       5
#
# ModuleNotFoundError: No module named 'utilities'

# %%
tsforest = TSForest()
